# %%
cd /home/lblondel/Documents/Harvard/ExtavourLab/projects/Project_Joe_DataViz/D3/
# Out:
# /home/lblondel/Documents/Harvard/ExtavourLab/projects/Project_Joe_DataViz/D3

# %%
import pandas as pd
import numpy as np

# %%
eggsize = pd.read_csv('./Data/dunntest_eggsize.csv')
mass = pd.read_csv('./Data/dunntest_mass.csv')
ovarno = pd.read_csv('./Data/dunntest_ovarno.csv')
wing = pd.read_csv('./Data/dunntest_winglength.csv')
devL1A = pd.read_csv('./Data/dunntest_devL1-A.csv')
devL1LP = pd.read_csv('./Data/dunntest_devL1LP.csv')
devLPA = pd.read_csv('./Data/dunntest_devLPA.csv')

# %%
data = []

def clean(gen):
    s = gen.split('_')
    r = []
    for i in s:
        if i == 'poor':
            r.append('P')
        elif i == 'rich':
            r.append('R')
        else:
            r.append('S')
    return ''.join(r)
           
pheno = 'eggsize'
for i in range(len(eggsize)):
    gen1, gen2 = eggsize['comparisons'][i].strip().split(' - ')
    if len(gen1) > 3:
        gen1 = clean(gen1)
    if len(gen2) > 3:
        gen2 = clean(gen2)    
    pval = str(eggsize['P.adjusted'][i])
    data.append([gen1, gen2, pheno, pval])
    data.append([gen2, gen1, pheno, pval])

pheno = 'mass'
for i in range(len(mass)):
    gen1, gen2 = mass['comparisons'][i].strip().split(' - ')
    if len(gen1) > 3:
        gen1 = clean(gen1)
    if len(gen2) > 3:
        gen2 = clean(gen2)
    pval = str(mass['P.adjusted'][i])
    data.append([gen1, gen2, pheno, pval])
    data.append([gen2, gen1, pheno, pval])


pheno = 'ovarno'
for i in range(len(ovarno)):
    gen1, gen2 = ovarno['comparisons'][i].strip().split(' - ')
    if len(gen1) > 3:
        gen1 = clean(gen1)
    if len(gen2) > 3:
        gen2 = clean(gen2)
    pval = str(ovarno['P.adjusted'][i])
    data.append([gen1, gen2, pheno, pval])
    data.append([gen2, gen1, pheno, pval])
    
pheno = 'winglength'
for i in range(len(wing)):
    gen1, gen2 = wing['comparisons'][i].strip().split(' - ')
    if len(gen1) > 3:
        gen1 = clean(gen1)
    if len(gen2) > 3:
        gen2 = clean(gen2)
    pval = str(wing['P.adjusted'][i])
    data.append([gen1, gen2, pheno, pval])
    data.append([gen2, gen1, pheno, pval])

pheno = 'devL1A'
for i in range(len(devL1A)):
    gen1, gen2 = devL1A['comparisons'][i].strip().split(' - ')
    if len(gen1) > 3:
        gen1 = clean(gen1)
    if len(gen2) > 3:
        gen2 = clean(gen2)
    pval = str(devL1A['P.adjusted'][i])
    data.append([gen1, gen2, pheno, pval])
    data.append([gen2, gen1, pheno, pval])

pheno = 'devL1LP'
for i in range(len(devL1LP)):
    gen1, gen2 = devL1LP['comparisons'][i].strip().split(' - ')
    if len(gen1) > 3:
        gen1 = clean(gen1)
    if len(gen2) > 3:
        gen2 = clean(gen2)
    pval = str(devL1LP['P.adjusted'][i])
    data.append([gen1, gen2, pheno, pval])
    data.append([gen2, gen1, pheno, pval])
    
pheno = 'devLPA'
for i in range(len(devLPA)):
    gen1, gen2 = devLPA['comparisons'][i].strip().split(' - ')
    if len(gen1) > 3:
        gen1 = clean(gen1)
    if len(gen2) > 3:
        gen2 = clean(gen2)
    pval = str(devLPA['P.adjusted'][i])
    data.append([gen1, gen2, pheno, pval])
    data.append([gen2, gen1, pheno, pval])
# Out:
#   File "<ipython-input-58-828e03280037>", line 21
#     gen2 = clean(gen2)    pval = str(eggsize['P.adjusted'][i])
#                              ^
# SyntaxError: invalid syntax

# %%
f = open('./matrix_data.tsv','w')
f.write('gen1\tgen2\tphenotype\tpvalue\n')
for l in data:
    f.write('\t'.join(l) + '\n')
f.close()

# %%
raw = pd.read_csv('./Data/tei_data_raw.csv')
raw
# Out:
#       no_id gen_id vial_id genvial_id diet_group lineage F2_diet F1_diet  \
# 0       392     F0       1       F0-1          P       P    poor     NaN
# 1       518     F0       6       F0-6          P       P    poor     NaN
# 2       393     F0       1       F0-1          P       P    poor     NaN
# 3       646     F0       8       F0-8          P       P    poor     NaN
# 4       512     F0       4       F0-4          P       P    poor     NaN
# 5       513     F0       4       F0-4          P       P    poor     NaN
# 6       521     F0       7       F0-7          P       P    poor     NaN
# 7       411     F0       5       F0-5          P       P    poor     NaN
# 8       536     F0      10      F0-10          P       P    poor     NaN
# 9       570     F0      10      F0-10          P       P    poor     NaN
# 10      610     F0      10      F0-10          P       P    poor     NaN
# 11      489     F0      11      F0-11          S       S     std     NaN
# 12      516     F0       5       F0-5          P       P    poor     NaN
# 13      339     F0       2       F0-2          P       P    poor     NaN
# 14      545     F0       8       F0-8          P       P    poor     NaN
# 15      633     F0      11      F0-11          P       P    poor     NaN
# 16      455     F0       5       F0-5          P       P    poor     NaN
# 17      565     F0       9       F0-9          P       P    poor     NaN
# 18      402     F0       3       F0-3          P       P    poor     NaN
# 19      631     F0       5       F0-5          S       S     std     NaN
# 20      537     F0      10      F0-10          P       P    poor     NaN
# 21      412     F0       5       F0-5          P       P    poor     NaN
# 22      609     F0       9       F0-9          P       P    poor     NaN
# 23      617     F0      12      F0-12          P       P    poor     NaN
# 24      650     F0      12      F0-12          P       P    poor     NaN
# 25      613     F0      11      F0-11          P       P    poor     NaN
# 26      520     F0       7       F0-7          P       P    poor     NaN
# 27      560     F0       7       F0-7          P       P    poor     NaN
# 28      272     F0       1       F0-1          P       P    poor     NaN
# 29      550     F0      10      F0-10          P       P    poor     NaN
# ...     ...    ...     ...        ...        ...     ...     ...     ...
# 1432   2071     F2       2       F2-2        PPP       P    poor    poor
# 1433   2179     F2       7       F2-7        PPP       P    poor    poor
# 1434   2197     F2       4       F2-4        PPP       P    poor    poor
# 1435   1872     F2       2       F2-2        PPR       P    rich    poor
# 1436   2051     F2       3       F2-3        PPS       P     std    poor
# 1437   2063     F2       7       F2-7        PPS       P     std    poor
# 1438   2092     F2       5       F2-5        PPS       P     std    poor
# 1439   2103     F2       6       F2-6        PPS       P     std    poor
# 1440   1904     F2       4       F2-4        PRP       P    poor    rich
# 1441   2187     F2       9       F2-9        PRP       P    poor    rich
# 1442   1889     F2       6       F2-6        PRR       P    rich    rich
# 1443   1960     F2       8       F2-8        PRR       P    rich    rich
# 1444   1962     F2       8       F2-8        PRR       P    rich    rich
# 1445   1968     F2       9       F2-9        PRR       P    rich    rich
# 1446   2025     F2       7       F2-7        PSP       P    poor     std
# 1447   1811     F2       7       F2-7        RPP       R    poor    poor
# 1448   1814     F2       8       F2-8        RPP       R    poor    poor
# 1449   1702     F2       6       F2-6        RPR       R    rich    poor
# 1450   1799     F2       9       F2-9        RPR       R    rich    poor
# 1451   1549     F2      2b      F2-2b        RRP       R    poor    rich
# 1452   1551     F2      2b      F2-2b        RRP       R    poor    rich
# 1453   1665     F2       6       F2-6        RRP       R    poor    rich
# 1454   1538     F2       6       F2-6        RRR       R    rich    rich
# 1455   1636     F2       8       F2-8        RRR       R    rich    rich
# 1456   1733     F2       7       F2-7        RRS       R     std    rich
# 1457   1458     F2       3       F2-3        RSR       R    rich     std
# 1458   1459     F2       3       F2-3        RSR       R    rich     std
# 1459   1460     F2       3       F2-3        RSR       R    rich     std
# 1460   1557     F2       6       F2-6        RSR       R    rich     std
# 1461   1606     F2       4       F2-4        RSS       R     std     std
#
#      F0_diet sex  mass_mg  dev_L1-LP  dev_LP-A  dev_L1-A  ovar_no  wing_length
# 0        NaN   f      0.8        7.5         4      11.5      NaN        1.431
# 1        NaN   f      0.9        7.5         4      11.5      NaN        1.477
# 2        NaN   f      0.9        7.5         4      11.5      NaN        1.514
# 3        NaN   f      0.9        9.5         4      13.5      NaN        1.531
# 4        NaN   f      1.5        7.5         4      11.5     25.0        1.535
# 5        NaN   f      0.9        7.5         4      11.5      NaN        1.575
# 6        NaN   f      1.1        7.5         4      11.5      NaN        1.578
# 7        NaN   f      1.0        6.5         4      10.5      NaN        1.618
# 8        NaN   f      0.9        6.5         4      10.5     14.0        1.638
# 9        NaN   f      0.8        7.5         3      10.5      NaN        1.640
# 10       NaN   f      0.6        8.5         4      12.5     20.0        1.649
# 11       NaN   f      1.4        5.5         4       9.5     36.0        1.670
# 12       NaN   f      0.9        7.5         4      11.5      NaN        1.679
# 13       NaN   f      1.0        6.5         5      11.5      NaN        1.684
# 14       NaN   f      1.2        6.5         4      10.5     19.0        1.689
# 15       NaN   f      1.3        7.5         4      11.5      NaN        1.691
# 16       NaN   f      1.0        6.5         4      10.5     20.0        1.696
# 17       NaN   f      1.5        7.5         4      11.5      NaN        1.705
# 18       NaN   f      0.9        7.5         4      11.5      NaN        1.707
# 19       NaN   f      1.4        9.5         5      14.5      NaN        1.715
# 20       NaN   f      0.9        6.5         4      10.5      NaN        1.719
# 21       NaN   f      1.0        6.5         4      10.5      NaN        1.722
# 22       NaN   f      0.9        8.5         4      12.5      NaN        1.727
# 23       NaN   f      1.2        7.5         4      11.5      NaN        1.744
# 24       NaN   f      0.9        8.5         4      12.5      NaN        1.747
# 25       NaN   f      1.1        7.5         4      11.5      NaN        1.748
# 26       NaN   f      1.1        7.5         4      11.5      NaN        1.751
# 27       NaN   f      1.2        8.5         4      12.5     14.0        1.755
# 28       NaN   f      1.1        6.5         4      10.5      NaN        1.755
# 29       NaN   f      1.6        6.5         4      10.5      NaN        1.758
# ...      ...  ..      ...        ...       ...       ...      ...          ...
# 1432    poor   f      1.6        5.5         6      11.5      NaN          NaN
# 1433    poor   f      1.5        6.5         5      11.5      NaN          NaN
# 1434    poor   f      1.2        8.5         4      12.5      NaN          NaN
# 1435    poor   f      1.4        4.5         3       7.5      NaN          NaN
# 1436    poor   f      1.6        5.5         4       9.5      NaN          NaN
# 1437    poor   f      1.6        4.5         5       9.5      NaN          NaN
# 1438    poor   f      1.4        5.5         5      10.5      NaN          NaN
# 1439    poor   f      1.8        5.5         5      10.5      NaN          NaN
# 1440    poor   f      1.4        5.5         4       9.5      NaN          NaN
# 1441    poor   f      1.5        7.5         4      11.5      NaN          NaN
# 1442    poor   f      1.5        4.5         4       8.5      NaN          NaN
# 1443    poor   f      1.8        4.5         4       8.5      NaN          NaN
# 1444    poor   f      1.2        4.5         5       9.5      NaN          NaN
# 1445    poor   f      1.6        4.5         4       8.5      NaN          NaN
# 1446    poor   f      1.3        5.5         6      11.5      NaN          NaN
# 1447    rich   f      1.1        6.5         4      10.5      NaN          NaN
# 1448    rich   f      1.3        5.5         4       9.5      NaN          NaN
# 1449    rich   f      1.6        3.5         4       7.5      NaN          NaN
# 1450    rich   f      1.5        4.5         4       8.5      NaN          NaN
# 1451    rich   f      1.0        5.5         5      10.5      NaN          NaN
# 1452    rich   f      0.8        5.5         5      10.5      NaN          NaN
# 1453    rich   f      1.0        5.5         4       9.5      NaN          NaN
# 1454    rich   f      1.6        3.5         5       8.5      NaN          NaN
# 1455    rich   f      1.6        4.5         4       8.5      NaN          NaN
# 1456    rich   f      1.5        5.5         4       9.5      NaN          NaN
# 1457    rich   f      1.5        4.5         4       8.5      NaN          NaN
# 1458    rich   f      1.4        4.5         4       8.5      NaN          NaN
# 1459    rich   f      1.6        4.5         4       8.5      NaN          NaN
# 1460    rich   f      1.3        3.5         5       8.5      NaN          NaN
# 1461    rich   f      1.3        5.5         4       9.5      NaN          NaN
#
# [1462 rows x 16 columns]

# %%
rawdata = []

# %%
for i in range(len(raw)):
    gen = raw['diet_group'][i]
    if not pd.isnull(raw['mass_mg'][i]):
        rawdata.append([gen, 'mass', str(raw['mass_mg'][i])])
    if not pd.isnull(raw['mass_mg'][i]):
        rawdata.append([gen, 'eggsize', str(np.random.normal(150,50))])
    if not pd.isnull(raw['ovar_no'][i]):
        rawdata.append([gen, 'ovarno', str(raw['ovar_no'][i])])
    if not pd.isnull(raw['wing_length'][i]):
        rawdata.append([gen, 'winglength', str(raw['wing_length'][i])])
    if not pd.isnull(raw['dev_L1-A'][i]):
        rawdata.append([gen, 'devL1A', str(raw['dev_L1-A'][i])])
    if not pd.isnull(raw['dev_L1-LP'][i]):
        rawdata.append([gen, 'devL1LP', str(raw['dev_L1-LP'][i])])
    if not pd.isnull(raw['dev_LP-A'][i]):
        rawdata.append([gen, 'devLPA', str(raw['dev_LP-A'][i])])

# %%
f = open('./rawdata.tsv','w')
f.write('gen\tphenotype\tvalue\n')
for l in rawdata:
    f.write('\t'.join(l) + '\n')
f.close()

# %%
a = ["#ffffd9","#edf8b1","#c7e9b4","#7fcdbb","#41b6c4","#1d91c0","#225ea8","#253494","#081d58"]

# %%
a.reverse()

# %%
print(a)
# Out:
# ['#081d58', '#253494', '#225ea8', '#1d91c0', '#41b6c4', '#7fcdbb', '#c7e9b4', '#edf8b1', '#ffffd9']
